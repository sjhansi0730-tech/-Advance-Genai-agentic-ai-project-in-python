# %% [markdown]
# Variable declaration using python(Variable=object=identifier)

# %% [markdown]
# Variable(object)=value(datatypes)

# %%
nit=1623
nit
# Out:
# 1623

# %%
1324=nit
1324
# Out:
#   Cell In[2], line 1
#     1324=nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
nit1=3534
nit1
# Out:
# 3534

# %%
1niit=23214
1nit
# Out:
#   Cell In[4], line 1
#     1niit=23214
#     ^
# SyntaxError: invalid decimal literal

# %%
nit=10
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 nit=10
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 10

# %%
nit_=623
nit_
# Out:
# 623

# %%
nit@=567
nit@
# Out:
#   Cell In[8], line 2
#     nit@
#         ^
# SyntaxError: invalid syntax

# %%
_nit=322
_nit
# Out:
# 322

# %%
import keywords
keyword.kwlist

# %%
'False',
 'None',
 'True',
 'and',
 'as',
 'assert',
 'async',
 'await',
 'break',
 'class',
 'continue',
 'def',
 'del',
 'elif',
 'else',
 'except',
 'finally',
 'for',
 'from',
 'global',
 'if',
 'import',
 'in',
 'is',
 'lambda',
 'return',
 'try',
 'while',
 'with',
 'yield'

# %%
len(keyword.kwlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 len(keyword.kwlist)
#
# NameError: name 'keyword' is not defined

# %%
For=424
For
# Out:
# 424
