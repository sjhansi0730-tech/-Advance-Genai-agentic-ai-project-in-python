# %% [markdown]
# #Datatypes in python

# %%
i=23(i=variable& 23=value)
i
# Out:
# 23

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140716286715496

# %%
f=11.37
f
# Out:
# 11.37

# %%
type(f)
# Out:
# float

# %%
gold_price=148000.12
gold_price
# Out:
# 148000.12

# %%
10+57
139-53
35*24
# Out:
# 840

# %%
print(10+57)
print(139-53)
print(35*24)
# Out:
# 67
# 86
# 840

# %%
type(f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 type(f1)
#
# NameError: name 'f1' is not defined

# %%
f1=2.4e2
f1
# Out:
# 240.0

# %%
f2=54.3e3
f2
# Out:
# 54300.0
