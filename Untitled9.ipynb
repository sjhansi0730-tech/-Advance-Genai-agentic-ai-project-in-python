# %% [markdown]
# #Boolean value

# %% [markdown]
# true=1 false=0

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %%
int(True)
# Out:
# 1
