# %% [markdown]
# #Dataypes in python

# %%
i=423
i
# Out:
# 423

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 2547089203248

# %%
f=43123.421
f
# Out:
# 43123.421

# %%
type(f)
# Out:
# float

# %%
gold_price = 324.34
gold_price
# Out:
# 324.34

# %%
type(gold_price)
# Out:
# float

# %%
312+414
4384-423
14*1234
# Out:
# 17276

# %%
print(312+414)
print(4384-423)
print(14*1234)
# Out:
# 726
# 3961
# 17276

# %%
f1 =4.23e1
f1
# Out:
# 42.3

# %%
type(f1)
# Out:
# float

# %%
f2=13.2e3
f2
# Out:
# 13200.0

# %%
f3=23.231e4
f3
# Out:
# 232310.0

# %% [markdown]
# #Boolean functions

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+True
# Out:
# 2

# %%
True+False-False
# Out:
# 1

# %%
True*True
# Out:
# 1

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# #complex

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.imag
# Out:
# 20.0

# %%
c.real
# Out:
# 10.0

# %% [markdown]
# #strings

# %%
s='naresh technology'
s
# Out:
# 'naresh technology'

# %%
type(s)
# Out:
# str

# %%
s[2]
# Out:
# 'r'

# %%
s[4:6]
# Out:
# 'sh'

# %%
s[:4]
# Out:
# 'nare'

# %%
s[3:]
# Out:
# 'esh technology'

# %%
s[1:3:6]
# Out:
# 'a'

# %%
s[:]
# Out:
# 'naresh technology'

# %%
s[::2]
# Out:
# 'nrs ehooy'

# %%
s[::-4]
# Out:
# 'yoesn'

# %%
s[::4]
# Out:
# 'nseoy'

# %% [markdown]
# Datatypes is completed
