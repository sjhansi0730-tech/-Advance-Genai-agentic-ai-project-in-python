# %% [markdown]
# #17th

# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
x = round(math.sqrt(25))
x
# Out:
# 5

# %%
math.floor(3.5)
# Out:
# 3

# %%
math.ceil(3.6)
# Out:
# 4

# %%
pow(2,5)
# Out:
# 32

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi=3.19
pi
# Out:
# 3.19

# %%
m.sqrt(81)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 m.sqrt(81)
#
# NameError: name 'm' is not defined

# %%
math.sqrt(81)
# Out:
# 9.0

# %%
import math as j

# %%
j.sqrt(81)
# Out:
# 9.0

# %%
import nareshitechnology as nit
import indianinstitutetechnology as iit

# %%
from math import sqrt,pow
print(pow(2,3))
print(m.sqrt(10))

# %%
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# #input()

# %%
input()
# Out:
#  hi
# 'hi'

# %%
input()
input()
# Out:
#  hi
#  hello
# 'hello'

# %%
x=input()
y=input()
z=x+y
print(z)
# Out:
#  6
#  34
# 634

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x=int(input())
y=int(input())
z=x+y
print(z)
# Out:
#  3
#  6
# 9

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x1=input(enter the 1st number')
y1=input(enter the 2nd number')
z1=x1+y1
print(z1)
# Out:
#  23
#  56
# 2356

# %%
x1=input('enter the 1st number')
y1=input('enter the 2nd number')
z1=x1+y1
print(z1)
# Out:
# enter the 1st number 139
# enter the 2nd number 278
# 139278

# %%
x1= int(input('enter the 1st number'))
y1=int(input('enter the 2nd number'))
z1=x1+y1
print(z1)
# Out:
# enter the 1st number 21
# enter the 2nd number 31
# 52

# %%
x2=input('enter username:')
y2=input('enter  roll:')
z2=x2+y2
print(z2)
# Out:
# enter username: john
# enter  roll: jonny
# johnjonny

# %%
st=input('enter a string')
print(st)
# Out:
# enter a string hi
# hi

# %%
st=input('enter a string')[1]
print(st)
# Out:
# enter a string hello
# e

# %%
st=input('enter a string')[1:4]
print(st)
# Out:
# enter a string welcome
# elc

# %%
st=input('enter a string')[1:4:9]
print(st)
# Out:
# enter a string hellownareshit
# e

# %%
st=input('enter a string')[1::]
print(st)
