# %% [markdown]
# variable declartion in pytho(variable=object=identifier)

# %% [markdown]
# variable(object)=value(datatype)

# %%
nit=312
nit
# Out:
# 312

# %%
312=nit
312
# Out:
#   Cell In[3], line 1
#     312=nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1nit=11
1nit
# Out:
#   Cell In[4], line 1
#     1nit=11
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1=321
nit1
# Out:
# 321

# %%
nit=23
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 nit=23
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit_=31
nit_
# Out:
# 31

# %%
nit@=34
nit@
# Out:
#   Cell In[8], line 2
#     nit@
#         ^
# SyntaxError: invalid syntax

# %%
_nit=42
_nit
# Out:
# 42

# %% [markdown]
#  10th-----#python datatypes

# %%
i=4
i
# Out:
# 4

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140720377472008

# %%
f=41.543
f
# Out:
# 41.543

# %%
type(f)
# Out:
# float

# %%
gold_price=14800.423
gold_price
# Out:
# 14800.423

# %%
type(gold_price)
# Out:
# float

# %%
10+3
324+54
235+543
# Out:
# 778

# %%
print(24+423)
print(423+441)
print(44*432)
# Out:
# 447
# 864
# 19008

# %%
f1=2.4e1
f1
# Out:
# 24.0

# %%
type(f1)
# Out:
# float

# %%
f=13.324e3
f
# Out:
# 13324.0

# %% [markdown]
# #Boolean value

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+True
# Out:
# 2

# %%
True+False-False
# Out:
# 1

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# #Complex

# %%
c=10+32j---#10where 10 = real part 32 = imaginary part where j=square root of-1
# Out:
#   Cell In[31], line 1
#     c=10+32j---#10where 10 = real part 32 = imaginary part where j=square root of-1
#                ^
# SyntaxError: invalid syntax

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %% [markdown]
# #11Th---- Integer,Float,Complex,Boolean

# %%
i=4
i
# Out:
# 4

# %%
type(i)
# Out:
# int

# %%
f=3.21
f
# Out:
# 3.21

# %%
type(f)
# Out:
# float

# %%
b=True
b1=False
c=b+b1
c
# Out:
# 1

# %%
type(c)
# Out:
# int

# %%
b=False
type(b)
# Out:
# bool

# %%
c=1+32j
c
# Out:
# (1+32j)

# %%
type(c)
# Out:
# complex

# %% [markdown]
# #String

# %%
'hello'
# Out:
# 'hello'

# %%
'hellow it'
# Out:
# 'hellow it'

# %%
s='python'
s
# Out:
# 'python'

# %%
type(s)
# Out:
# str

# %%
s[3]
# Out:
# 'h'

# %%
s[2:4]
# Out:
# 'th'

# %%
s[1:3:5]
# Out:
# 'y'

# %%
s[::2]
# Out:
# 'pto'

# %%
s[3::]
# Out:
# 'hon'

# %%
s[::-3]
# Out:
# 'nt'

# %%
len(s)
# Out:
# 6

# %% [markdown]
# #python typecasting

# %% [markdown]
# we will type cast all other data types to integer

# %%
int(2.4)
# Out:
# 2

# %%
int(2.3,3.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 int(2.3,3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(1+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 int(1+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('str')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 int('str')
#
# ValueError: invalid literal for int() with base 10: 'str'

# %%
int('10')
# Out:
# 10

# %% [markdown]
# other datatypes to float

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float(10+39j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 float(10+39j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# all other datatypes to bool

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(10+28j)
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %% [markdown]
# 13th

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(1.0,2.3)
# Out:
# (1+2.3j)

# %%
complex(10,3.6)
# Out:
# (10+3.6j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex(10)
# Out:
# (10+0j)

# %% [markdown]
# #String

# %%
str(10)
# Out:
# '10'

# %%
str(10+20j)
# Out:
# '(10+20j)'

# %%
str(str)
# Out:
# "<class 'str'>"

# %%
str(2.3)
# Out:
# '2.3'

# %% [markdown]
# #Python operators

# %%
x1, y1=10, 5

# %%
x1+y1
# Out:
# 15

# %%
x1*y1
# Out:
# 50

# %%
x1-y1
# Out:
# 5

# %%
 x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %% [markdown]
# Assignment operator

# %%
X = 3

# %%
x = X+3
x
# Out:
# 6

# %%
X+=2
X
# Out:
# 5

# %%
X*=3
X
# Out:
# 45

# %%
X//=2
X
# Out:
# 22

# %% [markdown]
# Unary opeartion

# %%
n=7
n
# Out:
# 7

# %%
m=-n
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# Relational Opeartor

# %%
a = 23
b = 24

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# False

# %%
a=b

# %%
a==b
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 23
# 23

# %%
a==b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# False

# %% [markdown]
# #Logical table

# %%
a = 5
b = 8

# %%
a < 7 and b < 9
# Out:
# True

# %%
a < 7 or b < 9
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 5
# 8

# %%
x = True
x
# Out:
# True

# %%
x = False
x
# Out:
# False

# %%
-True
# Out:
# -1

# %%
False
# Out:
# False

# %%
10+2*4-2
# Out:
# 16

# %%
num1=20
num2=42
add=num1+num2
print(add)
# Out:
# 62

# %% [markdown]
# 16th---Number System

# %%
26
# Out:
# 26

# %%
oct(43)
# Out:
# '0o53'

# %%
int(0o53)
# Out:
# 43

# %%
bin(32)
# Out:
# '0b100000'

# %%
int(0b100000)
# Out:
# 32

# %% [markdown]
# #Bitwise operator

# %%
a=2

# %%
-a
# Out:
# -5

# %%
~3
# Out:
# -4

# %%
~9
# Out:
# -10

# %%
10
# Out:
# 10

# %%
~23
# Out:
# -24

# %% [markdown]
# Bitwise And Or

# %%
12&13
# Out:
# 12

# %%
print(bin(12))
print(bin(20))
# Out:
# 0b1100
# 0b10100

# %%
12|13
# Out:
# 13

# %%
14|42
# Out:
# 46

# %%
bin(46)
# Out:
# '0b101110'

# %%
bin(53)
# Out:
# '0b110101'

# %%
bin(13)
# Out:
# '0b1101'

# %% [markdown]
# #Left shift and Right shift

# %%
12<<4
# Out:
# 192

# %%
12<<2
# Out:
# 48

# %%
34<<1
# Out:
# 68

# %%
45>>2
# Out:
# 11

# %%
45>>5
# Out:
# 1

# %%
25>>2
# Out:
# 6

# %%
13>>3
# Out:
# 1

# %% [markdown]
# #Print functions

# %% [markdown]
# with string

# %%
num1=20
num2=34
add=num1+num2
print(add)
# Out:
# 54

# %% [markdown]
# with format method

# %%
num1=23
num2=45
add=num1+num2
print('the addition of {} and {}is={}'.format(num1,num2,add))
# Out:
# the addition of 23 and 45is=68

# %% [markdown]
# f string method

# %%
num1=23
num2=45
add=num1+num2
print(f.'the addition of {num1} and {num2} is = {add}')
# Out:
#   Cell In[187], line 4
#     print(f.'the addition of {num1} and {num2} is = {add}')
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# print with end stmt

# %%
print('hi,end=--->')
print('good morning')
# Out:
# hi,end=--->
# good morning
